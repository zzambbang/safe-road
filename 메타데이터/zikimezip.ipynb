# %%
import pandas as pd

# %%
pd. read_csv('전국여성안심지킴이집표준데이터.csv', encoding='cp949')
# Out:
#             점포명    시도명 시군구명  시군구코드                       소재지도로명주소  \
# 0         부평베스트  인천광역시  부평구  28237              인천광역시 부평구 부평대로 24
# 1         부평프렌즈  인천광역시  부평구  28237            인천광역시 부평구 경원대로 1414
# 2         갈산행복점  인천광역시  부평구  28237                인천광역시 부평구 새갈로 6
# 3     인천광역시부개동점  인천광역시  부평구  28237        인천광역시 부평구 동수로128번길 17-4
# 4        부개크라운점  인천광역시  부평구  28237         인천광역시 부평구 경인로1058번길 13
# ...         ...    ...  ...    ...                            ...
# 2548  GS25 개봉으뜸  서울특별시  구로구  11530  서울특별시 구로구 경인로40길 41(개봉동,107호)
# 2549  GS25 구로미래  서울특별시  구로구  11530  서울특별시 구로구 경인로 661(신도림동,1104호)
# 2550    GS25 고척  서울특별시  구로구  11530       서울특별시 구로구 경인로47길 10(고척동)
# 2551  미니스톱 천왕역점  서울특별시  구로구  11530      서울특별시 구로구 오리로 1154-7(오류동)
# 2552   CU 마장현대점  서울특별시  성동구  11200            서울특별시 성동구 마장로39길 36
#
#                               소재지지번주소         위도          경도  여성안심지킴이집전화번호  \
# 0                                 NaN  37.493519  126.723307  032-526-1082
# ...

# %%
df=pd.read_csv('전국여성안심지킴이집표준데이터.csv', encoding='cp949')

# %%
df
# Out:
#             점포명    시도명 시군구명  시군구코드                       소재지도로명주소  \
# 0         부평베스트  인천광역시  부평구  28237              인천광역시 부평구 부평대로 24
# 1         부평프렌즈  인천광역시  부평구  28237            인천광역시 부평구 경원대로 1414
# 2         갈산행복점  인천광역시  부평구  28237                인천광역시 부평구 새갈로 6
# 3     인천광역시부개동점  인천광역시  부평구  28237        인천광역시 부평구 동수로128번길 17-4
# 4        부개크라운점  인천광역시  부평구  28237         인천광역시 부평구 경인로1058번길 13
# ...         ...    ...  ...    ...                            ...
# 2548  GS25 개봉으뜸  서울특별시  구로구  11530  서울특별시 구로구 경인로40길 41(개봉동,107호)
# 2549  GS25 구로미래  서울특별시  구로구  11530  서울특별시 구로구 경인로 661(신도림동,1104호)
# 2550    GS25 고척  서울특별시  구로구  11530       서울특별시 구로구 경인로47길 10(고척동)
# 2551  미니스톱 천왕역점  서울특별시  구로구  11530      서울특별시 구로구 오리로 1154-7(오류동)
# 2552   CU 마장현대점  서울특별시  성동구  11200            서울특별시 성동구 마장로39길 36
#
#                               소재지지번주소         위도          경도  여성안심지킴이집전화번호  \
# 0                                 NaN  37.493519  126.723307  032-526-1082
# ...

# %%
df.columns
# Out:
# Index(['점포명', '시도명', '시군구명', '시군구코드', '소재지도로명주소', '소재지지번주소', '위도', '경도',
#        '여성안심지킴이집전화번호', '관할경찰서명', '지정연도', '운영여부', '데이터기준일자', '제공기관코드', '제공기관명'],
#       dtype='object')

# %%
dfseoul=df[df['시도명'].str.contains("서울특별시")]
dfseoul
# Out:
#               점포명    시도명 시군구명  시군구코드                       소재지도로명주소  \
# 31      세븐일레븐 은천점  서울특별시  관악구  11620              서울특별시 관악구 봉천로 335
# 32    씨스페이스 구로공단점  서울특별시  관악구  11620                서울특별시 관악구 조원로 6
# 40           GS25  서울특별시  강서구  11500         서울특별시 강서구 가로공원로76길 100
# 57    세븐일레븐 신사시장점  서울특별시  관악구  11620     서울특별시 관악구 신림동 남부순환로153길 35
# 58       CU 개포사랑점  서울특별시  강남구  11680             서울특별시 강남구 선릉로10길 4
# ...           ...    ...  ...    ...                            ...
# 2548    GS25 개봉으뜸  서울특별시  구로구  11530  서울특별시 구로구 경인로40길 41(개봉동,107호)
# 2549    GS25 구로미래  서울특별시  구로구  11530  서울특별시 구로구 경인로 661(신도림동,1104호)
# 2550      GS25 고척  서울특별시  구로구  11530       서울특별시 구로구 경인로47길 10(고척동)
# 2551    미니스톱 천왕역점  서울특별시  구로구  11530      서울특별시 구로구 오리로 1154-7(오류동)
# 2552     CU 마장현대점  서울특별시  성동구  11200            서울특별시 성동구 마장로39길 36
#
#                               소재지지번주소         위도          경도  여성안심지킴이집전화번호  \
# ...

# %%
dfseoul_dropcolumns = dfseoul.drop(['시군구코드', '지정연도',
       '운영여부', '데이터기준일자', '제공기관코드', '관할경찰서명', '제공기관명'], axis='columns')
dfseoul_dropcolumns
# Out:
#               점포명    시도명 시군구명                       소재지도로명주소  \
# 31      세븐일레븐 은천점  서울특별시  관악구              서울특별시 관악구 봉천로 335
# 32    씨스페이스 구로공단점  서울특별시  관악구                서울특별시 관악구 조원로 6
# 40           GS25  서울특별시  강서구         서울특별시 강서구 가로공원로76길 100
# 57    세븐일레븐 신사시장점  서울특별시  관악구     서울특별시 관악구 신림동 남부순환로153길 35
# 58       CU 개포사랑점  서울특별시  강남구             서울특별시 강남구 선릉로10길 4
# ...           ...    ...  ...                            ...
# 2548    GS25 개봉으뜸  서울특별시  구로구  서울특별시 구로구 경인로40길 41(개봉동,107호)
# 2549    GS25 구로미래  서울특별시  구로구  서울특별시 구로구 경인로 661(신도림동,1104호)
# 2550      GS25 고척  서울특별시  구로구       서울특별시 구로구 경인로47길 10(고척동)
# 2551    미니스톱 천왕역점  서울특별시  구로구      서울특별시 구로구 오리로 1154-7(오류동)
# 2552     CU 마장현대점  서울특별시  성동구            서울특별시 성동구 마장로39길 36
#
#                               소재지지번주소         위도          경도  여성안심지킴이집전화번호
# 31                                NaN  37.485321  126.937863   02-871-1785
# 32                                NaN  37.483406  126.902725   02-856-4280
# ...

# %%
dfseoul_dropcolumns.to_csv("safe_road_888row.csv")

# %%
import folium

# %%
dfseoul_dropcolumns.columns
# Out:
# Index(['점포명', '시도명', '시군구명', '소재지도로명주소', '소재지지번주소', '위도', '경도',
#        '여성안심지킴이집전화번호'],
#       dtype='object')

# %%
dfseoul_dropcolumns['위도'].mean()
# Out:
# 37.544498305908235

# %%
dfseoul_dropcolumns['경도'].mean()
# Out:
# 127.00256645392744

# %%
folium.Marker?

# %%
df=dfseoul_dropcolumns

# %%
df
# Out:
#               점포명    시도명 시군구명                       소재지도로명주소  \
# 31      세븐일레븐 은천점  서울특별시  관악구              서울특별시 관악구 봉천로 335
# 32    씨스페이스 구로공단점  서울특별시  관악구                서울특별시 관악구 조원로 6
# 40           GS25  서울특별시  강서구         서울특별시 강서구 가로공원로76길 100
# 57    세븐일레븐 신사시장점  서울특별시  관악구     서울특별시 관악구 신림동 남부순환로153길 35
# 58       CU 개포사랑점  서울특별시  강남구             서울특별시 강남구 선릉로10길 4
# ...           ...    ...  ...                            ...
# 2548    GS25 개봉으뜸  서울특별시  구로구  서울특별시 구로구 경인로40길 41(개봉동,107호)
# 2549    GS25 구로미래  서울특별시  구로구  서울특별시 구로구 경인로 661(신도림동,1104호)
# 2550      GS25 고척  서울특별시  구로구       서울특별시 구로구 경인로47길 10(고척동)
# 2551    미니스톱 천왕역점  서울특별시  구로구      서울특별시 구로구 오리로 1154-7(오류동)
# 2552     CU 마장현대점  서울특별시  성동구            서울특별시 성동구 마장로39길 36
#
#                               소재지지번주소         위도          경도  여성안심지킴이집전화번호
# 31                                NaN  37.485321  126.937863   02-871-1785
# 32                                NaN  37.483406  126.902725   02-856-4280
# ...

# %%
map=folium.Map(location=[df_drop['위도'].mean(), df_drop['경도'].mean()])
for i in df_drop.index:
    folium.Marker([df_drop['위도'][i], df_drop['경도'][i]],
                 popup=df_drop['점포명'][i]).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for i in df_drop.index:
    folium.Marker([df_drop['위도'][i], df_drop['경도'][i]]).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
df['위도'].dropna()
# Out:
# 31      37.485321
# 32      37.483406
# 40      37.532824
# 57      37.484020
# 58      37.483116
#           ...
# 2548    37.495028
# 2549    37.509049
# 2550    37.500112
# 2551    37.487529
# 2552    37.568109
# Name: 위도, Length: 885, dtype: float64

# %%
df['경도'].dropna()
# Out:
# 31      126.937863
# 32      126.902725
# 40      126.838812
# 57      126.916308
# 58      127.060656
#            ...
# 2548    126.859022
# 2549    126.886987
# 2550    126.867161
# 2551    126.838806
# 2552    127.043710
# Name: 경도, Length: 878, dtype: float64

# %%
df_drop = df.dropna()
df_drop
# Out:
#               점포명    시도명 시군구명                       소재지도로명주소  \
# 57    세븐일레븐 신사시장점  서울특별시  관악구     서울특별시 관악구 신림동 남부순환로153길 35
# 59    세븐일레븐 신림점 B  서울특별시  관악구         서울특별시 관악구 신림동 호암로24길 6
# 93    세븐일레븐 길동제일점  서울특별시  강동구             서울특별시 강동구 천호대로1203
# 94    세븐일레븐 길동4호점  서울특별시  강동구               서울특별시 강동구 명일로210
# 95     미니스톱 명일스타점  서울특별시  강동구            서울특별시 강동구 고덕로38길 64
# ...           ...    ...  ...                            ...
# 2547   GS25 구로아울렛  서울특별시  구로구    서울특별시 구로구 경인로43길 18(고척동,1층)
# 2548    GS25 개봉으뜸  서울특별시  구로구  서울특별시 구로구 경인로40길 41(개봉동,107호)
# 2549    GS25 구로미래  서울특별시  구로구  서울특별시 구로구 경인로 661(신도림동,1104호)
# 2550      GS25 고척  서울특별시  구로구       서울특별시 구로구 경인로47길 10(고척동)
# 2552     CU 마장현대점  서울특별시  성동구            서울특별시 성동구 마장로39길 36
#
#                               소재지지번주소         위도          경도  여성안심지킴이집전화번호
# 57                서울특별시 관악구 신림동 511-4  37.484020  126.916308   02-830-6586
# 59               서울특별시 관악구 신림동 1531-1  37.469901  126.933532   02-878-0845
# ...

# %%
map=folium.Map(location=[df_drop['위도'].mean(), df_drop['경도'].mean()])

# %%
df['점포명'].dropna()
df
# Out:
#               점포명    시도명 시군구명                       소재지도로명주소  \
# 31      세븐일레븐 은천점  서울특별시  관악구              서울특별시 관악구 봉천로 335
# 32    씨스페이스 구로공단점  서울특별시  관악구                서울특별시 관악구 조원로 6
# 40           GS25  서울특별시  강서구         서울특별시 강서구 가로공원로76길 100
# 57    세븐일레븐 신사시장점  서울특별시  관악구     서울특별시 관악구 신림동 남부순환로153길 35
# 58       CU 개포사랑점  서울특별시  강남구             서울특별시 강남구 선릉로10길 4
# ...           ...    ...  ...                            ...
# 2548    GS25 개봉으뜸  서울특별시  구로구  서울특별시 구로구 경인로40길 41(개봉동,107호)
# 2549    GS25 구로미래  서울특별시  구로구  서울특별시 구로구 경인로 661(신도림동,1104호)
# 2550      GS25 고척  서울특별시  구로구       서울특별시 구로구 경인로47길 10(고척동)
# 2551    미니스톱 천왕역점  서울특별시  구로구      서울특별시 구로구 오리로 1154-7(오류동)
# 2552     CU 마장현대점  서울특별시  성동구            서울특별시 성동구 마장로39길 36
#
#                               소재지지번주소         위도          경도  여성안심지킴이집전화번호
# 31                                NaN  37.485321  126.937863   02-871-1785
# 32                                NaN  37.483406  126.902725   02-856-4280
# ...

# %%
folium.Marker?

# %%
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
for i in range(0, len(df)):
    folium.Marker([df['위도'][i],df['경도'][i]]).add_to(map)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-d903f70e1384> in <module>
#       1 for i in range(0, len(df)):
# ...
